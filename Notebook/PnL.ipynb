# %%
import sqlite3
import pandas as pd

# %%
# Create your connection.
cnx = sqlite3.connect('../orders_pnl.db')

# %%
df = pd.read_sql_query("SELECT * FROM pnl", cnx)

# %%
df[['time',"PnL"]].plot()
